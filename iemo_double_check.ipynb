# %%
import pandas as pd
import torch
import numpy as np

# %%
iemo = pd.read_pickle('data/iemo.pkl')
big_text = pd.read_pickle('data/more_text_IEMO.pkl')

# %%
iemo
# Out:
#          talker sentiment_label  dialog  \
# 0          MARY      frustrated       7
# 1         JAMES         neutral       7
# 2         JAMES         neutral       7
# 3         JAMES         neutral       7
# 4         JAMES         neutral       7
# ...         ...             ...     ...
# 7375    WILLIAM         excited     149
# 7376    WILLIAM         excited     149
# 7377    WILLIAM         excited     149
# 7378    WILLIAM         excited     149
# 7379  ELIZABETH         neutral     149
#
#                                         text_w_one_prev  sentiment  \
# 0                         MARY: What's he going to say?          0
# 1     MARY: What's he going to say? </s></s> JAMES: ...          1
# 2     JAMES: He saw it. </s></s> JAMES: He was out h...          1
# 3     JAMES: He was out here when it broke. </s></s>...          1
# 4     JAMES: Four o clock this morning.  I heard a c...          1
# ...                                                 ...        ...
# ...

# %%
big_text
# Out:
#                                                    text              index  \
# 0                              </s></s>MARY: Excuse me.     Ses01F_impro01
# 1     MARY: Excuse me.</s></s>JAMES: Do you have you...     Ses01F_impro01
# 2     MARY: Excuse me. JAMES: Do you have your forms...     Ses01F_impro01
# 3     MARY: Excuse me. JAMES: Do you have your forms...     Ses01F_impro01
# 4     MARY: Excuse me. JAMES: Do you have your forms...     Ses01F_impro01
# ...                                                 ...                ...
# 7375  WILLIAM: You better turn that off, I think. EL...  Ses05M_script03_2
# 7376  ELIZABETH: Why? WILLIAM: Because it's very lat...  Ses05M_script03_2
# 7377  ELIZABETH: There aren't any people upstairs.  ...  Ses05M_script03_2
# 7378  WILLIAM: Well, there are people downstairs, I ...  Ses05M_script03_2
# 7379  WILLIAM: Well, there are people downstairs, I ...  Ses05M_script03_2
#
# ...

# %%
big_test = big_text[big_text['split'] == "test"]
test = iemo[iemo['split'] == "test"]

# %%
test
# Out:
#          talker sentiment_label  dialog  \
# 3563    WILLIAM         neutral     129
# 3564  ELIZABETH         neutral     129
# 3565    WILLIAM         neutral     129
# 3566    WILLIAM         neutral     129
# 3567    WILLIAM      frustrated     129
# ...         ...             ...     ...
# 7375    WILLIAM         excited     149
# 7376    WILLIAM         excited     149
# 7377    WILLIAM         excited     149
# 7378    WILLIAM         excited     149
# 7379  ELIZABETH         neutral     149
#
#                                         text_w_one_prev  sentiment  \
# 3563                 WILLIAM: Why does that bother you?          1
# 3564  WILLIAM: Why does that bother you? </s></s> EL...          1
# 3565  ELIZABETH: She's been in New York three and a ...          1
# 3566  WILLIAM: Well maybe.  Maybe she just wanted to...          1
# 3567  WILLIAM: What did you mean? He lived next door...          0
# ...                                                 ...        ...
# ...

# %%
test[test['index'] == "Ses05F_impro01"]
# Out:
#          talker sentiment_label  dialog  \
# 3730  ELIZABETH         neutral     120
# 3731    WILLIAM         neutral     120
# 3732  ELIZABETH      frustrated     120
# 3733  ELIZABETH      frustrated     120
# 3734  ELIZABETH      frustrated     120
# 3735    WILLIAM         neutral     120
# 3736  ELIZABETH      frustrated     120
# 3737    WILLIAM      frustrated     120
# 3738  ELIZABETH      frustrated     120
# 3739    WILLIAM      frustrated     120
# 3740  ELIZABETH      frustrated     120
# 3741    WILLIAM      frustrated     120
# 3742  ELIZABETH      frustrated     120
# 3743    WILLIAM      frustrated     120
# 3744  ELIZABETH         neutral     120
# 3745    WILLIAM      frustrated     120
# 3746  ELIZABETH      frustrated     120
# 3747    WILLIAM      frustrated     120
# 3748  ELIZABETH      frustrated     120
# 3749    WILLIAM      frustrated     120
# 3750  ELIZABETH      frustrated     120
# 3751    WILLIAM      frustrated     120
# ...

# %%
big_test[big_test['index'] == "Ses05F_impro01"]
# Out:
#                                                    text           index split  \
# 5758               </s></s>ELIZABETH: Hi, I need an ID.  Ses05F_impro01  test
# 5759  ELIZABETH: Hi, I need an ID.</s></s>WILLIAM: a...  Ses05F_impro01  test
# 5760  ELIZABETH: Hi, I need an ID. WILLIAM: ahh Yeah...  Ses05F_impro01  test
# 5761  ELIZABETH: Hi, I need an ID. WILLIAM: ahh Yeah...  Ses05F_impro01  test
# 5762  ELIZABETH: Hi, I need an ID. WILLIAM: ahh Yeah...  Ses05F_impro01  test
# 5763  ELIZABETH: Hi, I need an ID. WILLIAM: ahh Yeah...  Ses05F_impro01  test
# 5764  ELIZABETH: Hi, I need an ID. WILLIAM: ahh Yeah...  Ses05F_impro01  test
# 5765  ELIZABETH: Hi, I need an ID. WILLIAM: ahh Yeah...  Ses05F_impro01  test
# 5766  ELIZABETH: Hi, I need an ID. WILLIAM: ahh Yeah...  Ses05F_impro01  test
# 5767  ELIZABETH: Hi, I need an ID. WILLIAM: ahh Yeah...  Ses05F_impro01  test
# 5768  ELIZABETH: Hi, I need an ID. WILLIAM: ahh Yeah...  Ses05F_impro01  test
# ...
