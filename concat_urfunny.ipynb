# %%
import pandas as pd

PATH = "data/"

# %%
df = pd.DataFrame()
for i in range(0,21):
    try:
        tmp = pd.read_pickle(f"{PATH}URFUNNY_df_sub_{i}.pkl")
        df = pd.concat([df, tmp]) 
    except:
        continue
df
# Out:
#                                                 sentence  \
# 0      [finally in desperation they went and they con...
# 1                they gave it back to the wise old woman
# 2      [the most fundamental way in which the third s...
# 3      and as the saying goes when angry you will mak...
# 4             [i tried to remember to go to the balcony]
# ...                                                  ...
# 20327  so i found that they had a friend a local acco...
# 20328  [so their scores had gone up from zero to perc...
# 20329                              just say to them cool
# 20330  [the worst in, they used everything that they ...
# 20331  a single child in front of a single computer w...
#
#                                                 features  \
# 0      [[finally, in, desperation, they, went, and, t...
# 1      [they, gave, it, back, to, the, wise, old, woman]
# 2      [[the, most, fundamental, way, in, which, the,...
# ...

# %%
# df.to_pickle("data/urfunny_small_combo.pkl")

# %%
pd.read_pickle("data/urfunny.pkl")
# Out:
#                                                 sentence  \
# 0      [finally in desperation they went and they con...
# 1                they gave it back to the wise old woman
# 2      [the most fundamental way in which the third s...
# 3      and as the saying goes when angry you will mak...
# 4             [i tried to remember to go to the balcony]
# ...                                                  ...
# 20327  so i found that they had a friend a local acco...
# 20328  [so their scores had gone up from zero to perc...
# 20329                              just say to them cool
# 20330  [the worst in, they used everything that they ...
# 20331  a single child in front of a single computer w...
#
#                                                 features  \
# 0      [[finally, in, desperation, they, went, and, t...
# 1      [they, gave, it, back, to, the, wise, old, woman]
# 2      [[the, most, fundamental, way, in, which, the,...
# ...

# %%
fail = df[df['bbox'] == "FAIL"]
fail
# Out:
#                                                 sentence  \
# 263    i'm here today to talk about autonomous flying...
# 441                                            very good
# 681                                         i have three
# 761    now i think that we can all agree that mathema...
# 1105                             should've been a dancer
# ...                                                  ...
# 19089                                 monkeys in the zoo
# 19145                          you can go ahead and play
# 19248  [so what if you wanted to try this yourself at...
# 19556  [a ted talk you mean like the one you made us ...
# 19619                  i don't know the million man swim
#
#                                                 features  \
# 263    [i'm, here, today, to, talk, about, autonomous...
# 441                                         [very, good]
# 681                                     [i, have, three]
# ...

# %%
df = pd.read_pickle(f"{PATH}URFUNNY_df_sub_3.pkl")
df
# Out:
#                                                sentence  \
# 3000  [thank you, i'm thrilled to be here, i'm going...
# 3001  this material actually has some traits that ma...
# 3002  [i'll tell you a little bit more, this materia...
# 3003  the components of this material are just water...
# 3004  [attributed smiles to descriptions of situatio...
# ...                                                 ...
# 3995  and i want to share some of those with you rig...
# 3996  [also going to need to grow more food with les...
# 3997          so it sort of leaves us feeling like this
# 3998  [another important message is this one gardens...
# 3999  and as i said before you never know who you mi...
#
#                                                features  \
# 3000  [[thank, you], [i'm, thrilled, to, be, here], ...
# 3001  [this, material, actually, has, some, traits, ...
# 3002  [[i'll, tell, you, a, little, bit, more], [thi...
# 3003  [the, components, of, this, material, are, jus...
# ...

# %%
bad_df = df[df['bbox']  == "FAIL"]

# %%
bad_df['video_timings'] , bad_df['video_path']
# Out:
# (114    (3.342, 7.782)
#  263     (2.355, 4.41)
#  306      (0.0, 4.021)
#  441    (5.068, 5.617)
#  482      (0.0, 0.948)
#  526      (0.0, 2.953)
#  680    (0.778, 5.378)
#  681    (5.647, 6.336)
#  761    (4.749, 8.341)
#  762    (1.766, 5.557)
#  884    (1.337, 5.627)
#  918     (0.379, 4.56)
#  Name: video_timings, dtype: object,
#  114    ../../data/urfunny2_videos/12503.mp4
#  263     ../../data/urfunny2_videos/7680.mp4
#  306     ../../data/urfunny2_videos/3450.mp4
#  441     ../../data/urfunny2_videos/7914.mp4
#  482    ../../data/urfunny2_videos/13704.mp4
#  526     ../../data/urfunny2_videos/2113.mp4
#  680     ../../data/urfunny2_videos/3419.mp4
#  681     ../../data/urfunny2_videos/3419.mp4
#  761    ../../data/urfunny2_videos/13450.mp4
#  762    ../../data/urfunny2_videos/13452.mp4
#  884    ../../data/urfunny2_videos/11165.mp4
#  918     ../../data/urfunny2_videos/2927.mp4
#  Name: video_path, dtype: object)

# %%
# Out:
# 1000
