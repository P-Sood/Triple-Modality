# %%
import pandas as pd
import spleeter
from spleeter.separator import Separator
import soundfile as sf

# %%
df_script = pd.read_pickle("/home/jupyter/multi-modal-emotion/data/tiktok_0_new.pkl")
df_cpu = pd.read_pickle("/home/jupyter/multi-modal-emotion/data/tiktok_0.pkl")

# %%
df_script.columns
# Out:
# Index(['name', 'content_label', 'content', 'text', 'video_path', 'audio_path',
#        'split', 'text_len', 'dialog', 'check', 'timings'],
#       dtype='object')

# %%
df_script['audio_path'][0]
# Out:
# '../data/tiktok_wav/test/educative/alexandereadie_6955257178760547590.mp4.wav'

# %%
separator = Separator('spleeter:2stems')
x , _ = sf.read(df_script['audio_path'][0])
y = separator.separate(x)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 'pretrained_models/2stems', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': gpu_options {
#   per_process_gpu_memory_fraction: 0.7
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_checkpoint_save_graph_def': True, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# ...

# %%
x.shape
# Out:
# (1319036, 2)

# %%
x.mean(1).shape
# Out:
# (1319036,)

# %%
y['vocals'].shape
# Out:
# (1319036, 2)

# %%
df_script[['audio_path','timings' , 'text']]
# Out:
#                                            audio_path  \
# 0   ../data/tiktok_wav/test/educative/alexanderead...
# 1   ../data/tiktok_wav/test/educative/viv_whnp_681...
# 2   ../data/tiktok_wav/test/educative/leanna.apa_6...
# 3   ../data/tiktok_wav/test/educative/mel.on.medic...
# 4   ../data/tiktok_wav/test/educative/contro_za_71...
# 5   ../data/tiktok_wav/test/educative/dickdocsg_70...
# 6   ../data/tiktok_wav/test/educative/intimacywith...
# 7   ../data/tiktok_wav/test/educative/thewhizdoc_6...
# 8   ../data/tiktok_wav/test/educative/doctor.siya_...
# 9   ../data/tiktok_wav/test/educative/doctor.shawn...
# 10  ../data/tiktok_wav/test/educative/sexedtok_716...
# 11  ../data/tiktok_wav/test/educative/haydenhappen...
# 12  ../data/tiktok_wav/test/educative/healthpeers_...
# 13  ../data/tiktok_wav/test/educative/creelehrman_...
# 14  ../data/tiktok_wav/test/educative/amolsmd_7154...
# 15  ../data/tiktok_wav/test/educative/drsexthrpst_...
# ...

# %%
df_cpu[['name','timings']]
# Out:
#                    name                                    timings
# 0        alexandereadie     (45.11080714632371, 74.65788570735259)
# 1              viv_whnp   (10.203910662122688, 10.423995009737098)
# 2            leanna.apa   (1.3800999075785583, 161.47168918669132)
# 3       mel.on.medicine    (0.6600390261300495, 265.3556896868899)
# 4             contro_za     (1.3202433322874176, 44.6882364292438)
# 5             dickdocsg     (6.123527912621359, 40.96360012135922)
# 6      intimacywithjess    (1.360230056980057, 138.88348949430198)
# 7            thewhizdoc   (20.655244577412116, 22.836854712041884)
# 8           doctor.siya   (10.789014964788732, 14.632226232394366)
# 9          doctor.shawn   (1.0201074184107841, 224.36362573164246)
# 10             sexedtok   (0.9001926369863014, 108.70326198630138)
# 11        haydenhappens   (0.5600909961685824, 144.10341201423097)
# 12          healthpeers    (9.802443196162585, 43.090740090886136)
# ...
